# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sp

# %%
sp2.__version__
# Out:
# '1.0.1'

# %% [markdown]
# H(q, p) = U(q)+K(p)<br>
# U(q) let's say is a normal that we want to draw from

# %%
norm = lambda q: sp.norm.pdf(q)
qq = np.linspace(-5,5,100)
plt.subplot(121)
plt.plot(qq, norm(qq))
plt.subplot(122)
log_q = -np.log(norm(qq))
plt.plot(qq, log_q)

# %%
K_p = lambda p: p**2 / 2*m
log_p = K_p(qq)

# %%
energy = 10

# %%
plt.plot(log_p, log_q)
