# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sp

# %%
sp2.__version__
# Out:
# '1.0.1'

# %% [markdown]
# H(q, p) = U(q)+K(p)<br>
# U(q) let's say is a normal that we want to draw from

# %%
norm = lambda q: sp.norm.pdf(q)
qq = np.linspace(-5,5,100)
plt.subplot(121)
plt.plot(qq, norm(qq))
plt.subplot(122)
plt.plot(qq, np.log(norm(qq)))
